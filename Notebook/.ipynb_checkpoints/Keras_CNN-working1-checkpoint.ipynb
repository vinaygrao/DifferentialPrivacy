# %%
import numpy as np
import keras

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense, Activation,BatchNormalization, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.layers.normalization import BatchNormalization
from keras.datasets import mnist
from keras import backend as K
(x_train, y_train),(x_test,y_test)=mnist.load_data()
num_classes=10




x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
input_shape = (x_train.shape[1], x_train.shape[1], 1)

# %%
#from tenserflow.keras.preprocessing import sequence
##x_train = sequence.pad_sequences(x_train, maxlen=80)
#x_test = sequence.pad_sequences(x_test, maxlen=80)
#from sklearn.preprocessing import StandardScaler
#Scaler = StandardScaler().fit(x_train)
#standardized_X = scaler.transform(x_train)
#standardized_X_test = scaler.transform(x_test)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
data_slice = 3000
x_train = x_train[:data_slice,:]
y_train = y_train[:data_slice,:]
x_test = x_test[:data_slice,:]
y_test = y_test[:data_slice,:]

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), padding=("same"), activation='relu', input_shape=x_train.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
#model.add(Activation("relu"))
model.add(Conv2D(32,(3,3), padding=("same"), activation='relu'))
#model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),padding=("same"),activation='relu'))
#model.add(Activation("relu"))
model.add(Conv2D(64,(3,3),padding=("same"),activation='relu'))
#model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
#model.add(Activation("relu"))
model.add(Dropout(0.5))
#model.add(Dense(32))
model.add(Dense(num_classes,activation='softmax'))
#model.add(Activation("softmax"))

# %%
model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=["accuracy"])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               295424
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 365,674
# Trainable params: 365,610
# Non-trainable params: 64
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train, batch_size=28, epochs=5,verbose=1,validation_data=(x_test,y_test))
# Out:
# Train on 3000 samples, validate on 3000 samples
# Epoch 1/5
# 3000/3000 [==============================] - 4s 1ms/step - loss: 1.4929 - acc: 0.4840 - val_loss: 0.4920 - val_acc: 0.8483
# Epoch 2/5
# 3000/3000 [==============================] - 3s 983us/step - loss: 0.4202 - acc: 0.8697 - val_loss: 0.2236 - val_acc: 0.9280
# Epoch 3/5
# 3000/3000 [==============================] - 3s 964us/step - loss: 0.2622 - acc: 0.9167 - val_loss: 0.2007 - val_acc: 0.9323
# Epoch 4/5
# 3000/3000 [==============================] - 3s 979us/step - loss: 0.2217 - acc: 0.9323 - val_loss: 0.1593 - val_acc: 0.9470
# Epoch 5/5
# 3000/3000 [==============================] - 3s 965us/step - loss: 0.1636 - acc: 0.9447 - val_loss: 0.1259 - val_acc: 0.9563

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
#import time
#from sklearn.manifold import TSNE
#time_start = time.time()
#tsne = TSNE(n_components=2,init='pca',  verbose=1, perplexity=40, n_iter=300)
#tsne_results = tsne.fit_transform(y_train)

# %%
choices = np.random.choice(np.arange(len(x_test)), len(x_test), replace=False)
x_sample, y_sample = x_test[choices], y_test[choices]
embeddings = model.predict(x_sample.reshape((len(x_sample), 28, 28, 1)))

# %%
# Perform t-distributed stochastic neighbor embedding.
import time
time_start = time.time()
from sklearn.manifold import TSNE
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
tsne = TSNE(n_components=2, init='pca',  random_state=0)
#trans_data = tsne.fit_transform(embeddings)
trans_data = tsne.fit_transform(model.predict(x_test.reshape((len(x_test), 28, 28, 1)))).T
trans_data1 = tsne.fit_transform(y_test).T
print(trans_data.shape)
print("t-SNE: %.2g sec" % (time.time() - time_start))

    
plt.figure(figsize=(16, 16))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
for i, c in zip(range(10), colors):
    plt.scatter(trans_data1[ i,0], trans_data1[ i,1], c=c, label=str(i))
plt.legend()
plt.show()
# Out:
# (2, 3000)
# t-SNE: 23 sec
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-107-745f9298af08> in <module>
#      15 colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
#      16 for i, c in zip(range(10), colors):
# ---> 17     plt.scatter(trans_data1[y_test == i,0], trans_data1[y_test == i,1], c=c, label=str(i))
#      18 plt.legend()
#      19 plt.show()
#
# IndexError: too many indices for array

# %%
plt.figure(figsize=(16, 16))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
for i, c in zip(range(10), colors):
    plt.scatter(trans_data[ i,0], trans_data[ i,1], c=c, label=str(i))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-2fdeb35358a8> in <module>
#       2 colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
#       3 for i, c in zip(range(10), colors):
# ----> 4     plt.scatter(trans_data[ i,0], trans_data[ i,1], c=c, label=str(i))
#       5 plt.legend()
#       6 plt.show()
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
fig = plt.figure(figsize=(60, 16))
from matplotlib.ticker import NullFormatter
#(fig, subplots) = plt.subplots(1, 1, figsize=(15, 8))
ax = fig.add_subplot(252)

plt.scatter(trans_data[0], trans_data[1],  cmap=plt.cm.rainbow)
plt.title("t-SNE (%.2g sec)" % (time.time()-time_start))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
ax = fig.add_subplot(251)
plt.scatter(trans_data[0], trans_data[1],  cmap=plt.cm.rainbow)
plt.title("t-SNE (%.2g sec)" % (time.time()-time_start))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\envs\PythonCPU\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(60, 16))
from matplotlib.ticker import NullFormatter
#(fig, subplots) = plt.subplots(1, 1, figsize=(15, 8))
ax = fig.add_subplot(252)

plt.scatter(trans_data[0], trans_data[1],  cmap=plt.cm.rainbow)
plt.title("t-SNE (%.2g sec)" % (time.time()-time_start))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')
plt.show()
